# %%
from yahoo_plot import *

df = get_crypto_volumes()
if df.empty:
    print("No data found — maybe the page structure changed.")
else:
    print(df)
    save_files(df)
    plot_volume_chart(df)
# Out:
#               symbol                     name    price change  change_pct  \
# 0        U  USDT-USD          Tether USDt USD    -0.00   None         NaN
# 1         B  BTC-USD              Bitcoin USD -2165.96   None         NaN
# 2   M  MPRO31258-USD         Max Property USD     0.00   None         0.0
# 3         E  ETH-USD             Ethereum USD   -73.79   None         NaN
# 4        X  XAUT-USD          Tether Gold USD    24.78   None         NaN
# 5        U  USDC-USD             USD Coin USD     0.00   None         NaN
# 6         S  SOL-USD               Solana USD    -7.92   None         NaN
# 7       F  FDUSD-USD    First Digital USD USD     0.00   None         NaN
# 8         X  XRP-USD                  XRP USD    -0.07   None         NaN
# 9   T  TIMI38905-USD            MetaArena USD    -0.00   None         NaN
# 10        B  BNB-USD                  BNB USD   -20.83   None         NaN
# 11       W  WETH-USD                 WETH USD   -73.62   None         NaN
# 12        B  BSU-USD  Baby Shark Universe USD    -0.02   None         NaN
# 13        Z  ZEC-USD                Zcash USD    24.78   None         NaN
# 14       D  DOGE-USD             Dogecoin USD    -0.01   None         NaN
# 15   S  SUI20947-USD                  Sui USD    -0.04   None         NaN
# 16        T  TRX-USD                 TRON USD     0.00   None         NaN
# 17     1  138565-USD                    1 USD    -0.00   None         0.0
# 18   S  SOL16116-USD       Wrapped Solana USD    -7.39   None         NaN
# 19       W  WBNB-USD          Wrapped BNB USD   -20.40   None         NaN
# 20       L  LINK-USD            Chainlink USD    -0.58   None         NaN
# 21        A  ADA-USD              Cardano USD    -0.02   None         NaN
# 22       V  VBNB-USD            Venus BNB USD    -0.52   None         NaN
# 23        L  LTC-USD             Litecoin USD    -2.07   None         NaN
# 24       A  AVAX-USD            Avalanche USD    -1.08   None         NaN
#
#           volume    market_cap
# 0   9.084900e+10  9.084900e+10
# 1   5.780200e+10  5.780200e+10
# 2   4.520000e+10  4.520000e+10
# 3   2.590200e+10  2.590200e+10
# 4   1.633800e+10  1.633800e+10
# 5   1.143100e+10  1.143100e+10
# 6   4.343000e+09  4.343000e+09
# 7   3.956000e+09  3.956000e+09
# 8   3.190000e+09  3.190000e+09
# 9   2.930000e+09  2.930000e+09
# 10  1.889000e+09  1.889000e+09
# 11  1.601000e+09  1.601000e+09
# 12  1.274000e+09  1.274000e+09
# 13  1.267000e+09  1.267000e+09
# 14  1.203000e+09  1.203000e+09
# 15  7.997130e+08  7.997130e+08
# 16  7.045670e+08  7.045670e+08
# 17  6.675840e+08  6.675840e+08
# 18  6.427690e+08  6.427690e+08
# 19  6.227360e+08  6.227360e+08
# 20  6.073290e+08  6.073290e+08
# 21  5.635080e+08  5.635080e+08
# 22  4.841580e+08  4.841580e+08
# 23  4.433870e+08  4.433870e+08
# 24  4.199830e+08  4.199830e+08
# 💾 Saved: crypto_most_active.csv, crypto_most_active.json
